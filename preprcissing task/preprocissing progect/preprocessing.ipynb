# %%
import pandas as pd
import numpy as np

# %%
def read_data_file(file_path):
    try:
        df = pd.read_csv(file_path)
        return df
    except FileNotFoundError:
        print("file not found")
    except Exception:
        print("could not read the file")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(df.columns.tolist())
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
df.duplicated().count()
# Out:
# np.int64(891)

# %%
df.drop_duplicates(inplace=True)

# %%
def drop_unnecessary_features(df, cols_to_drop):
    return df.drop(columns=cols_to_drop)

# %%
df = drop_unnecessary_features(df, cols_to_drop)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 df = drop_unnecessary_features(df, cols_to_drop)
#
# NameError: name 'cols_to_drop' is not defined

# %%
def check_data_type(df):
    result = pd.DataFrame({
        "datatype": df.dtypes,
        "unique_values": df.nunique()
    })
    
    return result.T

# %%
data_report = check_data_type(df)

data_report
# Out:
#               PassengerId Survived Pclass Name  Sex      Age  SibSp  Parch  \
# datatype            int64    int64  int64  str  str  float64  int64  int64
# unique_values         891        2      3  891    2       88      7      7
#
#               Ticket     Fare Cabin Embarked
# datatype         str  float64   str      str
# unique_values    681      248   147        3

# %%
file_path = "titanic.csv"

df = read_data_file(file_path)

if df is not None:
    print("original data:")
    display(df.head())

    print("original shape:", df.shape)

    df = drop_unnecessary_features(df, cols_to_drop)

    print("data after removing unnecessary features:")
    display(df.head())

    print("new shape:", df.shape)

    print("data quality report:")
    display(check_data_type(df))
# Out:
# original data:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...
